# %%
from selenium import webdriver
import time
from bs4 import BeautifulSoup
import pandas as pd

# %%
url = "https://finance.yahoo.com/losers/?count=100&offset=0"

# %%
driver = webdriver.Chrome()
driver.get(url)
time.sleep(5)

# %%
soup = BeautifulSoup(driver.page_source,'html.parser')
driver.quit()

# %%
table = soup.find('table' , class_ = "W(100%)")

# %%
table
# Out:
# <table class="W(100%)"><thead><tr class="C($tertiaryColor) BdB Bdbc($seperatorColor)"><th class="Ta(start) Pstart(6px) Pend(10px) Miw(90px) Fz(xs) Py(5px)! Bgc($lv3BgColor) Va(m) Cur(p) Bgc($hoverBgColor):h Fw(400)! Ta(start) Start(0) Pend(10px) Pos(st) Bgc($lv3BgColor) Z(1) Ta(start)!"><label class="Ta(c) Pos(r) Va(tb) Pend(5px) D(n)--print" data-id=""><input aria-label="Select All" class="Pos(a) Op(0) checkbox" type="checkbox"/><svg class="Va(m)! H(16px) W(16px) checkbox:f+Stk($linkColor)! checkbox:f+Fill($linkColor)! Stk($plusGray) Fill($plusGray) Cur(p)" data-icon="checkbox-unchecked" height="16" style="stroke-width:0;vertical-align:bottom" viewbox="0 0 24 24" width="16"><path d="M3 3h18v18H3V3zm19-2H2c-.553 0-1 .448-1 1v20c0 .552.447 1 1 1h20c.552 0 1-.448 1-1V2c0-.552-.448-1-1-1z"></path></svg></label>Symbol<div class="W(3px) Pend(5px) Pos(a) Start(100%) T(0) H(100%) Bg($pfColumnFakeShadowGradient) Pe(n)"></div></th><th class="Ta(start) Px(10px) Fz(xs) Py(5px)! Bgc($lv3BgColor) Va(m) Cur(p) Bgc($hoverBgColor):h Fw(400)!">Name</th><th class="Ta(end) Pstart(20px) Fz(xs) Py(5px)! Bgc($lv3BgColor) Va(m) Cur(p) Bgc($hoverBgColor):h Fw(400)!">Price (Intraday)</th><th class="Ta(end) Pstart(20px) Fz(xs) Py(5px)! Bgc($lv3BgColor) Va(m) Cur(p) Bgc($hoverBgColor):h Fw(400)!">Change</th><th class="Ta(end) Pstart(20px) Fz(xs) Py(5px)! Bgc($lv3BgColor) Va(m) Cur(p) Bgc($hoverBgColor):h C($primaryColor) Fw(500)">% Change<svg class="Va(b)! W(14px) H(14px) Fill($primaryColor)! Stk($primaryColor)! Cur(p)" data-icon="caret-up" height="48" style="fill:#000;stroke:#000;stroke-width:0;vertical-align:bottom" viewbox="0 0 48 48" width="48"><path d="M24.21 16.03L11.48 28.76c-.78.78-.78 2.047 0 2.827.78.78 2.048.78 2.83 0l9.898-9.9 9.9 9.9c.78.78 2.047.78 2.827 0 .78-.78.78-2.047 0-2.828L24.21 16.03z"></path></svg></th><th class="Ta(end) Pstart(20px) Fz(xs) Py(5px)! Bgc($lv3BgColor) Va(m) Cur(p) Bgc($hoverBgColor):h Fw(400)!">Volume</th><th class="Ta(end) Pstart(20px) Fz(xs) Py(5px)! Bgc($lv3BgColor) Va(m) Fw(400)!">Avg Vol (3 month)</th><th class="Ta(end) Pstart(20px) Pend(10px) W(120px) Fz(xs) Py(5px)! Bgc($lv3BgColor) Va(m) Cur(p) Bgc($hoverBgColor):h Fw(400)!">Market Cap</th><th class="Ta(end) Pstart(20px) Fz(xs) Py(5px)! Bgc($lv3BgColor) Va(m) Cur(p) Bgc($hoverBgColor):h Fw(400)!">PE Ratio (TTM)</th><th class="Ta(end) Pstart(20px) Pend(6px) Fz(xs) Py(5px)! Bgc($lv3BgColor) Va(m) Fw(400)!">52 Week Range</th></tr></thead><tbody><tr class="simpTblRow Bgc($hoverBgColor):h BdB Bdbc($seperatorColor) Bdbc($tableBorderBlue):h H(32px) Bgc($lv2BgColor)"><td aria-label="Symbol" class="Va(m) Ta(start) Pstart(6px) Pend(10px) Miw(90px) Start(0) Pend(10px) simpTblRow:h_Bgc($hoverBgColor) Pos(st) Bgc($lv3BgColor) Z(1) Bgc($lv2BgColor) Ta(start)! Fz(s)" colspan=""><label class="Ta(c) Pos(r) Va(tb) Pend(5px) D(n)--print" data-id="portfolio-checkbox"><input aria-label="Select ABR" class="Pos(a) Op(0) checkbox" type="checkbox"/><svg class="Va(m)! H(16px) W(16px) checkbox:f+Stk($linkColor)! checkbox:f+Fill($linkColor)! Stk($plusGray) Fill($plusGray) Cur(p)" data-icon="checkbox-unchecked" height="16" style="stroke-width:0;vertical-align:bottom" viewbox="0 0 24 24" width="16"><path d="M3 3h18v18H3V3zm19-2H2c-.553 0-1 .448-1 1v20c0 .552.447 1 1 1h20c.552 0 1-.448 1-1V2c0-.552-.448-1-1-1z"></path></svg></label><a class="Fw(600) C($linkColor)" data-test="quoteLink" href="/quote/ABR/" title="Arbor Realty Trust, Inc.">ABR</a><div class="W(3px) Pos(a) Start(100%) T(0) H(100%) Bg($pfColumnFakeShadowGradient) Pe(n) Pend(5px)"></div></td><td aria-label="Name" class="Va(m) Ta(start) Px(10px) Fz(s)" colspan="">Arbor Realty Trust, Inc.</td><td aria-label="Price (Intraday)" class="Va(m) Ta(end) Pstart(20px) Fw(600) Fz(s)" colspan=""><fin-streamer active="" class="" data-field="regularMarketPrice" data-pricehint="2" data-symbol="ABR" data-test="colorChange" data-trend="none" value="12.89">12.89</fin-streamer></td><td aria-label="Change" class="Va(m) Ta(end) Pstart(20px) Fw(600) ...

# %%
headers = []
thead = table.find('thead')
tr = thead.find('tr')
for th in tr.find_all('th'):
    text = th.get_text(strip=True)
    headers.append(text)
headers
# Out:
# ['Symbol',
#  'Name',
#  'Price (Intraday)',
#  'Change',
#  '% Change',
#  'Volume',
#  'Avg Vol (3 month)',
#  'Market Cap',
#  'PE Ratio (TTM)',
#  '52 Week Range']

# %%
rows = []
tbody = table.find('tbody')
trows = tbody.find_all('tr')
for tr in trows:
    row = []
    for td in tr.find_all('td'):
        row_text = td.get_text(strip=True)
        row.append(row_text)
    rows.append(row)

# %%
rows
# Out:
# [['ABR',
#   'Arbor Realty Trust, Inc.',
#   '12.89',
#   '-2.64',
#   '-17.00%',
#   '38.125M',
#   '4.164M',
#   '2.43B',
#   '8.06',
#   ''],
#  ['BWLP',
#   'BW LPG Limited',
#   '15.70',
#   '-1.53',
#   '-8.88%',
#   '806,081',
#   '195,650',
#   '2.15B',
#   '4.30',
#   ''],
#  ['GRFS',
#   'Grifols, S.A.',
#   '8.26',
#   '-0.59',
#   '-6.67%',
#   '3.44M',
#   '1.453M',
#   '6.765B',
#   '82.60',
#   ''],
#  ['WFC',
#   'Wells Fargo & Company',
#   '56.54',
#   '-3.62',
#   '-6.02%',
#   '52.887M',
#   '18.251M',
#   '197.117B',
#   '11.59',
#   ''],
#  ['ALGN',
#   'Align Technology, Inc.',
#   '242.65',
#   '-13.65',
#   '-5.33%',
#   '1.03M',
#   '766,596',
#   '18.267B',
#   '40.04',
#   ''],
#  ['BILI',
#   'Bilibili Inc.',
#   '16.71',
#   '-0.91',
#   '-5.16%',
#   '7.178M',
#   '7.423M',
#   '7.24B',
#   'N/A',
#   ''],
#  ['ASX',
#   'ASE Technology Holding Co., Ltd.',
#   '11.90',
#   '-0.60',
#   '-4.80%',
#   '9.591M',
#   '5.685M',
#   '25.702B',
#   '24.29',
#   ''],
#  ['ZIM',
#   'ZIM Integrated Shipping Services Ltd.',
#   '17.05',
#   '-0.82',
#   '-4.59%',
#   '9.266M',
#   '5.845M',
#   '2.051B',
#   'N/A',
#   ''],
#  ['NTNX',
#   'Nutanix, Inc.',
#   '54.28',
#   '-2.42',
#   '-4.27%',
#   '5.245M',
#   '2.627M',
#   '13.388B',
#   'N/A',
#   ''],
#  ['NVST',
#   'Envista Holdings Corporation',
#   '16.04',
#   '-0.70',
#   '-4.18%',
#   '3.094M',
#   '2.409M',
#   '2.757B',
#   'N/A',
#   ''],
#  ['GDRX',
#   'GoodRx Holdings, Inc.',
#   '7.71',
#   '-0.32',
#   '-3.99%',
#   '1.52M',
#   '1.277M',
#   '2.894B',
#   'N/A',
#   ''],
#  ['HGTY',
#   'Hagerty, Inc.',
#   '10.97',
#   '-0.45',
#   '-3.94%',
#   '130,191',
#   '118,730',
#   '3.694B',
#   '137.12',
#   ''],
#  ['HMY',
#   'Harmony Gold Mining Company Limited',
#   '9.62',
#   '-0.39',
#   '-3.90%',
#   '5.269M',
#   '4.21M',
#   '6.334B',
#   '12.18',
#   ''],
#  ['VRT',
#   'Vertiv Holdings Co',
#   '89.67',
#   '-3.19',
#   '-3.44%',
#   '10.27M',
#   '9.409M',
#   '33.568B',
#   '85.40',
#   ''],
#  ['BOWL',
#   'Bowlero Corp.',
#   '13.75',
#   '-0.48',
#   '-3.37%',
#   '497,516',
#   '807,443',
#   '2.047B',
#   '24.12',
#   ''],
#  ['HNHPF',
#   'Hon Hai Precision Industry Co., Ltd.',
#   '13.39',
#   '-0.45',
#   '-3.25%',
#   '43,385',
#   '144,780',
#   '92.987B',
#   '20.29',
#   ''],
#  ['AMKBY',
#   'A.P. Møller - Mærsk A/S',
#   '7.84',
#   '-0.26',
#   '-3.21%',
#   '190,387',
#   '199,614',
#   '24.795B',
#   '14.79',
#   ''],
#  ['LYFT',
#   'Lyft, Inc.',
#   '13.11',
#   '-0.42',
#   '-3.10%',
#   '12.359M',
#   '13.599M',
#   '5.29B',
#   'N/A',
#   ''],
#  ['WST',
#   'West Pharmaceutical Services, Inc.',
#   '322.98',
#   '-10.32',
#   '-3.10%',
#   '627,848',
#   '551,241',
#   '23.644B',
#   '42.55',
#   ''],
#  ['DAL',
#   'Delta Air Lines, Inc.',
#   '43.62',
#   '-1.37',
#   '-3.05%',
#   '16.677M',
#   '8.431M',
#   '28.153B',
#   '6.26',
#   ''],
#  ['LFST',
#   'LifeStance Health Group, Inc.',
#   '5.33',
#   '-0.16',
#   '-2.91%',
#   '1.499M',
#   '1.59M',
#   '2.038B',
#   'N/A',
#   ''],
#  ['URBN',
#   'Urban Outfitters, Inc.',
#   '46.67',
#   '-1.39',
#   '-2.89%',
#   '1.9M',
#   '1.615M',
#   '4.359B',
#   '14.86',
#   ''],
#  ['CRC',
#   'California Resources Corporation',
#   '51.40',
#   '-1.51',
#   '-2.85%',
#   '952,597',
#   '914,709',
#   '4.584B',
#   '14.48',
#   ''],
#  ['BIIB',
#   'Biogen Inc.',
#   '230.06',
#   '-6.74',
#   '-2.85%',
#   '1.464M',
#   '1.115M',
#   '33.496B',
#   '28.72',
#   ''],
#  ['SMTC',
#   'Semtech Corporation',
#   '35.86',
#   '-1.04',
#   '-2.82%',
#   '2.453M',
#   '2.113M',
#   '2.318B',
#   'N/A',
#   ''],
#  ['CNQ',
#   'Canadian Natural Resources Limited',
#   '35.53',
#   '-1.02',
#   '-2.79%',
#   '5.74M',
#   '4.673M',
#   '77.165B',
#   '14.33',
#   ''],
#  ['HUBS',
#   'HubSpot, Inc.',
#   '476.13',
#   '-13.64',
#   '-2.78%',
#   '1.857M',
#   '786,964',
#   '24.265B',
#   'N/A',
#   ''],
#  ['META',
#   'Meta Platforms, Inc.',
#   '498.87',
#   '-13.83',
#   '-2.70%',
#   '19.584M',
#   '14.948M',
#   '1.265T',
#   '28.74',
#   ''],
#  ['CROX',
#   'Crocs, Inc.',
#   '139.24',
#   '-3.65',
#   '-2.55%',
#   '1.407M',
#   '1.205M',
#   '8.452B',
#   '10.80',
#   ''],
#  ['VERA',
#   'Vera Therapeutics, Inc.',
#   '36.62',
#   '-0.95',
#   '-2.53%',
#   '441,111',
#   '779,038',
#   '2.003B',
#   'N/A',
#   '']]

# %%
df = pd.DataFrame(rows , columns = headers)
df
# Out:
#    Symbol                                   Name Price (Intraday)  Change  \
# 0     ABR               Arbor Realty Trust, Inc.            12.89   -2.64
# 1    BWLP                         BW LPG Limited            15.70   -1.53
# 2    GRFS                          Grifols, S.A.             8.26   -0.59
# 3     WFC                  Wells Fargo & Company            56.54   -3.62
# 4    ALGN                 Align Technology, Inc.           242.65  -13.65
# 5    BILI                          Bilibili Inc.            16.71   -0.91
# 6     ASX       ASE Technology Holding Co., Ltd.            11.90   -0.60
# 7     ZIM  ZIM Integrated Shipping Services Ltd.            17.05   -0.82
# 8    NTNX                          Nutanix, Inc.            54.28   -2.42
# 9    NVST           Envista Holdings Corporation            16.04   -0.70
# 10   GDRX                  GoodRx Holdings, Inc.             7.71   -0.32
# 11   HGTY                          Hagerty, Inc.            10.97   -0.45
# 12    HMY    Harmony Gold Mining Company Limited             9.62   -0.39
# 13    VRT                     Vertiv Holdings Co            89.67   -3.19
# 14   BOWL                          Bowlero Corp.            13.75   -0.48
# 15  HNHPF   Hon Hai Precision Industry Co., Ltd.            13.39   -0.45
# 16  AMKBY                A.P. Møller - Mærsk A/S             7.84   -0.26
# 17   LYFT                             Lyft, Inc.            13.11   -0.42
# 18    WST     West Pharmaceutical Services, Inc.           322.98  -10.32
# 19    DAL                  Delta Air Lines, Inc.            43.62   -1.37
# 20   LFST          LifeStance Health Group, Inc.             5.33   -0.16
# 21   URBN                 Urban Outfitters, Inc.            46.67   -1.39
# 22    CRC       California Resources Corporation            51.40   -1.51
# 23   BIIB                            Biogen Inc.           230.06   -6.74
# 24   SMTC                    Semtech Corporation            35.86   -1.04
# 25    CNQ     Canadian Natural Resources Limited            35.53   -1.02
# 26   HUBS                          HubSpot, Inc.           476.13  -13.64
# 27   META                   Meta Platforms, Inc.           498.87  -13.83
# 28   CROX                            Crocs, Inc.           139.24   -3.65
# 29   VERA                Vera Therapeutics, Inc.            36.62   -0.95
#
#    % Change   Volume Avg Vol (3 month) Market Cap PE Ratio (TTM) 52 Week Range
# 0   -17.00%  38.125M            4.164M      2.43B           8.06
# 1    -8.88%  806,081           195,650      2.15B           4.30
# 2    -6.67%    3.44M            1.453M     6.765B          82.60
# 3    -6.02%  52.887M           18.251M   197.117B          11.59
# 4    -5.33%    1.03M           766,596    18.267B          40.04
# 5    -5.16%   7.178M            7.423M      7.24B            N/A
# 6    -4.80%   9.591M            5.685M    25.702B          24.29
# 7    -4.59%   9.266M            5.845M     2.051B            N/A
# 8    -4.27%   5.245M            2.627M    13.388B            N/A
# 9    -4.18%   3.094M            2.409M     2.757B            N/A
# 10   -3.99%    1.52M            1.277M     2.894B            N/A
# 11   -3.94%  130,191           118,730     3.694B         137.12
# 12   -3.90%   5.269M             4.21M     6.334B          12.18
# 13   -3.44%   10.27M            9.409M    33.568B          85.40
# 14   -3.37%  497,516           807,443     2.047B          24.12
# 15   -3.25%   43,385           144,780    92.987B          20.29
# 16   -3.21%  190,387           199,614    24.795B          14.79
# 17   -3.10%  12.359M           13.599M      5.29B            N/A
# 18   -3.10%  627,848           551,241    23.644B          42.55
# 19   -3.05%  16.677M            8.431M    28.153B           6.26
# 20   -2.91%   1.499M             1.59M     2.038B            N/A
# 21   -2.89%     1.9M            1.615M     4.359B          14.86
# 22   -2.85%  952,597           914,709     4.584B          14.48
# 23   -2.85%   1.464M            1.115M    33.496B          28.72
# 24   -2.82%   2.453M            2.113M     2.318B            N/A
# 25   -2.79%    5.74M            4.673M    77.165B          14.33
# 26   -2.78%   1.857M           786,964    24.265B            N/A
# 27   -2.70%  19.584M           14.948M     1.265T          28.74
# 28   -2.55%   1.407M            1.205M     8.452B          10.80
# 29   -2.53%  441,111           779,038     2.003B            N/A

# %%
Top_losers = df.drop('52 Week Range' ,axis=1)

# %%
Top_losers.shape
# Out:
# (30, 9)

# %%
Top_losers.to_csv("Top_Losers.csv",index=False)
